# %%
import pandas as pd

# %%
races_df=pd.read_csv("../data/raw/races.csv")
races_df

# %%
results_df=pd.read_csv("../data/raw/results.csv")
results_df

# %%
races_results=races_df.merge(results_df)

# %%
races_results

# %%
driver_standingsdf=pd.read_csv("../data/raw/driver_standings.csv")
drivers_df=pd.read_csv("../data/raw/driver_standings.csv")
driver_standings_df= driver_standingsdf.fillna(0)

# %%
results= driver_standings_df.merge(drivers_df, how='left', on= 'driverId')
results_filtered = results[results['position'] == 1]

# %%
circuits_df=pd.read_csv("../data/raw/circuits.csv")

# %%
circuits_df["country"].unique()

# %%
races_df=pd.read_csv("../data/raw/races.csv")
races_new=races_df['name'].str.split(' ',n=1,expand=True)
races_df['name'].unique()

# %%
races_df['name'].replace(to_replace={'Australian' : 'Australia','Malaysian': 'Malaysia'})

# %%
'Australia', 'Malaysia', 'Bahrain', 'Spain', 'Turkey', 'Monaco',
       'Canada', 'France', 'UK', 'Germany', 'Hungary', 'Belgium', 'Italy',
       'Singapore', 'Japan', 'China', 'Brazil', 'USA', 'Austria', 'UAE',
       'Argentina', 'Portugal', 'South Africa', 'Mexico', 'Korea',
       'Netherlands', 'Sweden', 'Morocco', 'Switzerland', 'India',
       'Russia', 'Azerbaijan', 'Vietnam']

# %% [markdown]
# ## All constructors files into one

# %%
constructors_df=pd.read_csv("../data/raw/constructors.csv")
consrtuctor_results_df=pd.read_csv("../data/raw/constructor_results.csv")
constructor_standings_df=pd.read_csv("../data/raw/constructor_standings.csv")
races_df=pd.read_csv("../data/raw/races.csv")
constructors_df.drop(columns=['url'],inplace=True)

# %%
race_const_df= consrtuctor_results_df.merge(races_df,on='raceId',how='left')

race_const_df.rename(columns={'name':'races_name'},inplace=True)
race_const_df.drop(columns=['url'],inplace=True)

# %%
race_const_df= race_const_df.merge(constructors_df,on='constructorId',how='left')
race_const_df.rename(columns={'name':'constructor_name','nationality':'constructor_nationality'},inplace=True)

# %%
race_const_df.head(20)
# Out:
#     constructorResultsId  raceId  constructorId  points status  year  round  \
# 0                      1      18              1    14.0     \N  2008      1
# 1                      2      18              2     8.0     \N  2008      1
# 2                      3      18              3     9.0     \N  2008      1
# 3                      4      18              4     5.0     \N  2008      1
# 4                      5      18              5     2.0     \N  2008      1
# 5                      6      18              6     1.0     \N  2008      1
# 6                      7      18              7     0.0     \N  2008      1
# 7                      8      18              8     0.0     \N  2008      1
# 8                      9      18              9     0.0     \N  2008      1
# 9                     10      18             10     0.0     \N  2008      1
# 10                    11      18             11     0.0     \N  2008      1
# 11                    12      19              6    10.0     \N  2008      2
# 12                    13      19              2    11.0     \N  2008      2
# 13                    14      19              1    10.0     \N  2008      2
# 14                    15      19              7     5.0     \N  2008      2
# 15                    16      19              9     2.0     \N  2008      2
# 16                    17      19              4     1.0     \N  2008      2
# 17                    18      19             11     0.0     \N  2008      2
# 18                    19      19             10     0.0     \N  2008      2
# 19                    20      19              3     0.0     \N  2008      2
#
#     circuitId             races_name        date      time constructorRef  \
# 0           1  Australian Grand Prix  2008-03-16  04:30:00        mclaren
# 1           1  Australian Grand Prix  2008-03-16  04:30:00     bmw_sauber
# 2           1  Australian Grand Prix  2008-03-16  04:30:00       williams
# 3           1  Australian Grand Prix  2008-03-16  04:30:00        renault
# 4           1  Australian Grand Prix  2008-03-16  04:30:00     toro_rosso
# 5           1  Australian Grand Prix  2008-03-16  04:30:00        ferrari
# 6           1  Australian Grand Prix  2008-03-16  04:30:00         toyota
# 7           1  Australian Grand Prix  2008-03-16  04:30:00    super_aguri
# 8           1  Australian Grand Prix  2008-03-16  04:30:00       red_bull
# 9           1  Australian Grand Prix  2008-03-16  04:30:00    force_india
# 10          1  Australian Grand Prix  2008-03-16  04:30:00          honda
# 11          2   Malaysian Grand Prix  2008-03-23  07:00:00        ferrari
# 12          2   Malaysian Grand Prix  2008-03-23  07:00:00     bmw_sauber
# 13          2   Malaysian Grand Prix  2008-03-23  07:00:00        mclaren
# 14          2   Malaysian Grand Prix  2008-03-23  07:00:00         toyota
# 15          2   Malaysian Grand Prix  2008-03-23  07:00:00       red_bull
# 16          2   Malaysian Grand Prix  2008-03-23  07:00:00        renault
# 17          2   Malaysian Grand Prix  2008-03-23  07:00:00          honda
# 18          2   Malaysian Grand Prix  2008-03-23  07:00:00    force_india
# 19          2   Malaysian Grand Prix  2008-03-23  07:00:00       williams
#
#    constructor_name constructor_nationality
# 0           McLaren                 British
# 1        BMW Sauber                  German
# 2          Williams                 British
# 3           Renault                  French
# 4        Toro Rosso                 Italian
# 5           Ferrari                 Italian
# 6            Toyota                Japanese
# 7       Super Aguri                Japanese
# 8          Red Bull                Austrian
# 9       Force India                  Indian
# 10            Honda                Japanese
# 11          Ferrari                 Italian
# 12       BMW Sauber                  German
# 13          McLaren                 British
# 14           Toyota                Japanese
# 15         Red Bull                Austrian
# 16          Renault                  French
# 17            Honda                Japanese
# 18      Force India                  Indian
# 19         Williams                 British

# %%
race_const_df=race_const_df.merge(constructor_standings_df,on=['constructorId','raceId'],how='left')
race_const_df.rename(columns={'points':'constructor_point'},inplace=True)

# %%
race_const_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11680 entries, 0 to 11679
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   constructorResultsId     11680 non-null  int64
#  1   raceId                   11680 non-null  int64
#  2   constructorId            11680 non-null  int64
#  3   points_x                 11680 non-null  float64
#  4   status                   11680 non-null  object
#  5   year                     11680 non-null  int64
#  6   round                    11680 non-null  int64
#  7   circuitId                11680 non-null  int64
#  8   races_name               11680 non-null  object
#  9   date                     11680 non-null  object
#  10  time                     11680 non-null  object
#  11  constructorRef           11680 non-null  object
#  12  constructor_name         11680 non-null  object
#  13  constructor_nationality  11680 non-null  object
#  14  constructorStandingsId   11543 non-null  float64
#  15  points_y                 11543 non-null  float64
#  16  position                 11543 non-null  float64
#  17  positionText             11543 non-null  object
#  18  wins                     11543 non-null  float64
# dtypes: float64(5), int64(6), object(8)
# memory usage: 1.8+ MB

# %%
# constructorResults <- left_join(constructorResults, constructors %>% select(-url) %>% rename(name_constructor = name), by='constructorId')

# constructorResults <- left_join(constructorResults, constructorStandings %>% rename(point_constructor = points) %>% select(-X), by=c('constructorId','raceId'))

# %%
new_df=consrtuctor_results_df.merge(constructors_df,on='constructorId', how='left')

# %%
new_df.drop(columns=['status'],inplace=True)

# %%
new_df.rename(columns={'name':'constructor_name','nationality':'constructor_nationality','url':'constructor_url'},inplace=True)
new_df
# Out:
#        constructorResultsId  raceId  constructorId  points constructorRef  \
# 0                         1      18              1    14.0        mclaren
# 1                         2      18              2     8.0     bmw_sauber
# 2                         3      18              3     9.0       williams
# 3                         4      18              4     5.0        renault
# 4                         5      18              5     2.0     toro_rosso
# ...                     ...     ...            ...     ...            ...
# 11675                 16175    1042            211     6.0   racing_point
# 11676                 16176    1042              4     6.0        renault
# 11677                 16177    1042             51     0.0           alfa
# 11678                 16178    1042              3     0.0       williams
# 11679                 16179    1042            210     0.0           haas
#
#       constructor_name constructor_nationality  \
# 0              McLaren                 British
# 1           BMW Sauber                  German
# 2             Williams                 British
# 3              Renault                  French
# 4           Toro Rosso                 Italian
# ...                ...                     ...
# 11675     Racing Point                 British
# 11676          Renault                  French
# 11677       Alfa Romeo                 Italian
# 11678         Williams                 British
# 11679     Haas F1 Team                American
#
#                                          constructor_url
# 0                   http://en.wikipedia.org/wiki/McLaren
# 1                http://en.wikipedia.org/wiki/BMW_Sauber
# 2      http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3      http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4       http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso
# ...                                                  ...
# 11675  http://en.wikipedia.org/wiki/Racing_Point_F1_Team
# 11676  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 11677  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...
# 11678  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 11679          http://en.wikipedia.org/wiki/Haas_F1_Team
#
# [11680 rows x 8 columns]

# %%
constructor_standings_df=pd.read_csv("../data/raw/constructor_standings.csv")
# w=constructor_standings_df.loc[constructor_standings_df['wins']==1].count()
constructor_standings_df
# Out:
#        constructorStandingsId  raceId  constructorId  points  position  \
# 0                           1      18              1    14.0         1
# 1                           2      18              2     8.0         3
# 2                           3      18              3     9.0         2
# 3                           4      18              4     5.0         4
# 4                           5      18              5     2.0         5
# ...                       ...     ...            ...     ...       ...
# 12431                   27608    1042              4   120.0         5
# 12432                   27609    1042             51     5.0         8
# 12433                   27610    1042              3     0.0        10
# 12434                   27611    1042              9   226.0         2
# 12435                   27612    1042            210     3.0         9
#
#       positionText  wins
# 0                1     1
# 1                3     0
# 2                2     0
# 3                4     0
# 4                5     0
# ...            ...   ...
# 12431            5     0
# 12432            8     0
# 12433           10     0
# 12434            2     1
# 12435            9     0
#
# [12436 rows x 7 columns]

# %%
new_cons_df=constructor_standings_df.merge(new_df,on=['raceId','constructorId'], how='left')
new_cons_df.head(20)
# Out:
#     constructorStandingsId  raceId  constructorId  points_x  position  \
# 0                        1      18              1      14.0         1
# 1                        2      18              2       8.0         3
# 2                        3      18              3       9.0         2
# 3                        4      18              4       5.0         4
# 4                        5      18              5       2.0         5
# 5                        6      18              6       1.0         6
# 6                        7      19              1      24.0         1
# 7                        8      19              2      19.0         2
# 8                        9      19              3       9.0         4
# 9                       10      19              4       6.0         5
# 10                      11      19              5       2.0         8
# 11                      12      19              6      11.0         3
# 12                      13      19              7       5.0         6
# 13                      14      19              9       2.0         7
# 14                      15      19             11       0.0         9
# 15                      16      19             10       0.0        10
# 16                      17      19              8       0.0        11
# 17                      18      20              1      28.0         3
# 18                      19      20              2      30.0         1
# 19                      20      20              3      10.0         4
#
#    positionText  wins  constructorResultsId  points_y constructorRef  \
# 0             1     1                   1.0      14.0        mclaren
# 1             3     0                   2.0       8.0     bmw_sauber
# 2             2     0                   3.0       9.0       williams
# 3             4     0                   4.0       5.0        renault
# 4             5     0                   5.0       2.0     toro_rosso
# 5             6     0                   6.0       1.0        ferrari
# 6             1     1                  14.0      10.0        mclaren
# 7             2     0                  13.0      11.0     bmw_sauber
# 8             4     0                  20.0       0.0       williams
# 9             5     0                  17.0       1.0        renault
# 10            8     0                  22.0       0.0     toro_rosso
# 11            3     1                  12.0      10.0        ferrari
# 12            6     0                  15.0       5.0         toyota
# 13            7     0                  16.0       2.0       red_bull
# 14            9     0                  18.0       0.0          honda
# 15           10     0                  19.0       0.0    force_india
# 16           11     0                  21.0       0.0    super_aguri
# 17            3     1                  25.0       4.0        mclaren
# 18            1     0                  24.0      11.0     bmw_sauber
# 19            4     0                  28.0       1.0       williams
#
#            name nationality                                                url
# 0       McLaren     British               http://en.wikipedia.org/wiki/McLaren
# 1    BMW Sauber      German            http://en.wikipedia.org/wiki/BMW_Sauber
# 2      Williams     British  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3       Renault      French  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4    Toro Rosso     Italian   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso
# 5       Ferrari     Italian      http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 6       McLaren     British               http://en.wikipedia.org/wiki/McLaren
# 7    BMW Sauber      German            http://en.wikipedia.org/wiki/BMW_Sauber
# 8      Williams     British  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 9       Renault      French  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 10   Toro Rosso     Italian   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso
# 11      Ferrari     Italian      http://en.wikipedia.org/wiki/Scuderia_Ferrari
# 12       Toyota    Japanese         http://en.wikipedia.org/wiki/Toyota_Racing
# 13     Red Bull    Austrian       http://en.wikipedia.org/wiki/Red_Bull_Racing
# 14        Honda    Japanese       http://en.wikipedia.org/wiki/Honda_Racing_F1
# 15  Force India      Indian  http://en.wikipedia.org/wiki/Racing_Point_Forc...
# 16  Super Aguri    Japanese        http://en.wikipedia.org/wiki/Super_Aguri_F1
# 17      McLaren     British               http://en.wikipedia.org/wiki/McLaren
# 18   BMW Sauber      German            http://en.wikipedia.org/wiki/BMW_Sauber
# 19     Williams     British  http://en.wikipedia.org/wiki/Williams_Grand_Pr...

# %%
new_cons_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12436 entries, 0 to 12435
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   constructorStandingsId  12436 non-null  int64
#  1   raceId                  12436 non-null  int64
#  2   constructorId           12436 non-null  int64
#  3   points_x                12436 non-null  float64
#  4   position                12436 non-null  int64
#  5   positionText            12436 non-null  object
#  6   wins                    12436 non-null  int64
#  7   constructorResultsId    11543 non-null  float64
#  8   points_y                11543 non-null  float64
#  9   constructorRef          11543 non-null  object
#  10  name                    11543 non-null  object
#  11  nationality             11543 non-null  object
#  12  url                     11543 non-null  object
# dtypes: float64(3), int64(5), object(5)
# memory usage: 1.3+ MB

# %%
#look up the rows with win==1
cons_no1=new_cons_df.loc[new_cons_df['wins']==1]
cons_no1_new=cons_no1[['wins','name']]

# %%
#group the winners by their names and take the count of wins within each constructor
cons_gb=cons_no1_new.groupby(['name']).count()

# %%
cons_gb.sort_values(by=['wins'],ascending=False)
# cons_gb.merge(constructors_df)
# Out:
#                  wins
# name
# Ferrari           189
# McLaren           125
# Williams          112
# Brabham            70
# BRM                60
# Tyrrell            55
# Red Bull           47
# Renault            37
# Benetton           37
# Mercedes           29
# Team Lotus         29
# Ligier             29
# Jordan             24
# Lotus F1           22
# March              19
# Cooper-Climax      13
# Cooper-Maserati    12
# BMW Sauber         12
# Lotus-Ford         11
# Lotus-Climax       11
# Honda              10
# Hesketh             7
# Eagle-Weslake       7
# Shadow              6
# McLaren-Ford        6
# Brabham-Climax      6
# Penske              6
# Porsche             6
# Toro Rosso          5
# AlphaTauri          5
# Wolf                5
# Matra-Ford          4
# Brabham-Repco       4
# Stewart             3
# Brabham-Ford        2
# Lotus-BRM           2
# Cooper              1
# Brawn               1
# Vanwall             1

# %%
results_df=pd.read_csv("../data/raw/results.csv")
drivers_df=pd.read_csv("../data/raw/drivers.csv")
drivers_df.drop(columns=['number','url'],inplace=True) # since most of the columns have \n values
drivers_df
# Out:
#      driverId   driverRef code   forename     surname         dob nationality
# 0           1    hamilton  HAM      Lewis    Hamilton  1985-01-07     British
# 1           2    heidfeld  HEI       Nick    Heidfeld  1977-05-10      German
# 2           3     rosberg  ROS       Nico     Rosberg  1985-06-27      German
# 3           4      alonso  ALO   Fernando      Alonso  1981-07-29     Spanish
# 4           5  kovalainen  KOV     Heikki  Kovalainen  1981-10-19     Finnish
# ..        ...         ...  ...        ...         ...         ...         ...
# 843       845    sirotkin  SIR     Sergey    Sirotkin  1995-08-27     Russian
# 844       846      norris  NOR      Lando      Norris  1999-11-13     British
# 845       847     russell  RUS     George     Russell  1998-02-15     British
# 846       848       albon  ALB  Alexander       Albon  1996-03-23        Thai
# 847       849      latifi  LAT   Nicholas      Latifi  1995-06-29    Canadian
#
# [848 rows x 7 columns]

# %%
results_drivers_df=results_df.merge(drivers_df,on="driverId",how="inner")

# %%
results_drivers_df.rename(columns={"points":"driver_points"},inplace=True)
results_drivers_df
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1            27      19         1              1     22     9        5
# 2            57      20         1              1     22     3       13
# 3            69      21         1              1     22     5        3
# 4            90      22         1              1     22     3        2
# ...         ...     ...       ...            ...    ...   ...      ...
# 24855     24776    1038       849              3      6    20       11
# 24856     24800    1039       849              3      6    19       \N
# 24857     24821    1040       849              3      6    20       16
# 24858     24839    1041       849              3      6    18       14
# 24859     24863    1042       849              3      6    20       18
#
#       positionText  positionOrder  driver_points  ...  rank fastestLapTime  \
# 0                1              1           10.0  ...     2       1:27.452
# 1                5              5            4.0  ...     3       1:35.462
# 2               13             13            0.0  ...    19       1:35.520
# 3                3              3            6.0  ...     3       1:22.017
# 4                2              2            8.0  ...     2       1:26.529
# ...            ...            ...            ...  ...   ...            ...
# 24855           11             11            0.0  ...    16       1:24.999
# 24856            R             15            0.0  ...    14       2:11.365
# 24857           16             16            0.0  ...    18       1:41.044
# 24858           14             14            0.0  ...    13       1:31.377
# 24859           18             18            0.0  ...    19       1:21.859
#
#       fastestLapSpeed statusId driverRef code  forename   surname         dob  \
# 0             218.300        1  hamilton  HAM     Lewis  Hamilton  1985-01-07
# 1             209.033        1  hamilton  HAM     Lewis  Hamilton  1985-01-07
# 2             203.969       11  hamilton  HAM     Lewis  Hamilton  1985-01-07
# 3             204.323        1  hamilton  HAM     Lewis  Hamilton  1985-01-07
# 4             222.085        1  hamilton  HAM     Lewis  Hamilton  1985-01-07
# ...               ...      ...       ...  ...       ...       ...         ...
# 24855         245.353        1    latifi  LAT  Nicholas    Latifi  1995-06-29
# 24856         143.736        4    latifi  LAT  Nicholas    Latifi  1995-06-29
# 24857         208.352       11    latifi  LAT  Nicholas    Latifi  1995-06-29
# 24858         202.816        1    latifi  LAT  Nicholas    Latifi  1995-06-29
# 24859         204.629       12    latifi  LAT  Nicholas    Latifi  1995-06-29
#
#       nationality
# 0         British
# 1         British
# 2         British
# 3         British
# 4         British
# ...           ...
# 24855    Canadian
# 24856    Canadian
# 24857    Canadian
# 24858    Canadian
# 24859    Canadian
#
# [24860 rows x 24 columns]

# %%
constructors_df.rename(columns={'name':'constructor_name','nationality':'constructor_nationality'},inplace=True)
constructors_df
# Out:
#      constructorId constructorRef      constructor_name  \
# 0                1        mclaren               McLaren
# 1                2     bmw_sauber            BMW Sauber
# 2                3       williams              Williams
# 3                4        renault               Renault
# 4                5     toro_rosso            Toro Rosso
# ..             ...            ...                   ...
# 206            209          manor        Manor Marussia
# 207            210           haas          Haas F1 Team
# 208            211   racing_point          Racing Point
# 209            212    alpha_tauri  Scuderia Alpha Tauri
# 210            213     alphatauri            AlphaTauri
#
#     constructor_nationality                                                url
# 0                   British               http://en.wikipedia.org/wiki/McLaren
# 1                    German            http://en.wikipedia.org/wiki/BMW_Sauber
# 2                   British  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3                    French  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4                   Italian   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso
# ..                      ...                                                ...
# 206                 British      http://en.wikipedia.org/wiki/Manor_Motorsport
# 207                American          http://en.wikipedia.org/wiki/Haas_F1_Team
# 208                 British  http://en.wikipedia.org/wiki/Racing_Point_F1_Team
# 209                 Italian  http://en.wikipedia.org/wiki/Scuderia_Alpha_Tauri
# 210                 Italian   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
#
# [211 rows x 5 columns]

# %%
res_driver_const_df=results_drivers_df.merge(constructors_df,on="constructorId",how="inner")

# %%
res_driver_const_df.rename(columns={'nationality':'driver_nationality',})
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1            27      19         1              1     22     9        5
# 2            57      20         1              1     22     3       13
# 3            69      21         1              1     22     5        3
# 4            90      22         1              1     22     3        2
# ...         ...     ...       ...            ...    ...   ...      ...
# 24855     23289     964       839            209     31    20       21
# 24856     23308     965       839            209     31    22       18
# 24857     23333     966       839            209     31    20       21
# 24858     23346     967       839            209     31    22       12
# 24859     23369     968       839            209     31    20       13
#
#       positionText  positionOrder  driver_points  ...  driverRef code  \
# 0                1              1           10.0  ...   hamilton  HAM
# 1                5              5            4.0  ...   hamilton  HAM
# 2               13             13            0.0  ...   hamilton  HAM
# 3                3              3            6.0  ...   hamilton  HAM
# 4                2              2            8.0  ...   hamilton  HAM
# ...            ...            ...            ...  ...        ...  ...
# 24855           21             21            0.0  ...       ocon  OCO
# 24856           18             18            0.0  ...       ocon  OCO
# 24857           21             21            0.0  ...       ocon  OCO
# 24858           12             12            0.0  ...       ocon  OCO
# 24859           13             13            0.0  ...       ocon  OCO
#
#       forename   surname         dob driver_nationality constructorRef  \
# 0        Lewis  Hamilton  1985-01-07            British        mclaren
# 1        Lewis  Hamilton  1985-01-07            British        mclaren
# 2        Lewis  Hamilton  1985-01-07            British        mclaren
# 3        Lewis  Hamilton  1985-01-07            British        mclaren
# 4        Lewis  Hamilton  1985-01-07            British        mclaren
# ...        ...       ...         ...                ...            ...
# 24855  Esteban      Ocon  1996-09-17             French          manor
# 24856  Esteban      Ocon  1996-09-17             French          manor
# 24857  Esteban      Ocon  1996-09-17             French          manor
# 24858  Esteban      Ocon  1996-09-17             French          manor
# 24859  Esteban      Ocon  1996-09-17             French          manor
#
#        constructor_name constructor_nationality  \
# 0               McLaren                 British
# 1               McLaren                 British
# 2               McLaren                 British
# 3               McLaren                 British
# 4               McLaren                 British
# ...                 ...                     ...
# 24855    Manor Marussia                 British
# 24856    Manor Marussia                 British
# 24857    Manor Marussia                 British
# 24858    Manor Marussia                 British
# 24859    Manor Marussia                 British
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1               http://en.wikipedia.org/wiki/McLaren
# 2               http://en.wikipedia.org/wiki/McLaren
# 3               http://en.wikipedia.org/wiki/McLaren
# 4               http://en.wikipedia.org/wiki/McLaren
# ...                                              ...
# 24855  http://en.wikipedia.org/wiki/Manor_Motorsport
# 24856  http://en.wikipedia.org/wiki/Manor_Motorsport
# 24857  http://en.wikipedia.org/wiki/Manor_Motorsport
# 24858  http://en.wikipedia.org/wiki/Manor_Motorsport
# 24859  http://en.wikipedia.org/wiki/Manor_Motorsport
#
# [24860 rows x 28 columns]

# %%
res_driver_const_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24860 entries, 0 to 24859
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   resultId                 24860 non-null  int64
#  1   raceId                   24860 non-null  int64
#  2   driverId                 24860 non-null  int64
#  3   constructorId            24860 non-null  int64
#  4   number                   24860 non-null  object
#  5   grid                     24860 non-null  int64
#  6   position                 24860 non-null  object
#  7   positionText             24860 non-null  object
#  8   positionOrder            24860 non-null  int64
#  9   driver_points            24860 non-null  float64
#  10  laps                     24860 non-null  int64
#  11  time                     24860 non-null  object
#  12  milliseconds             24860 non-null  object
#  13  fastestLap               24860 non-null  object
#  14  rank                     24860 non-null  object
#  15  fastestLapTime           24860 non-null  object
#  16  fastestLapSpeed          24860 non-null  object
#  17  statusId                 24860 non-null  int64
#  18  driverRef                24860 non-null  object
#  19  code                     24860 non-null  object
#  20  forename                 24860 non-null  object
#  21  surname                  24860 non-null  object
#  22  dob                      24860 non-null  object
#  23  nationality              24860 non-null  object
#  24  constructorRef           24860 non-null  object
#  25  constructor_name         24860 non-null  object
#  26  constructor_nationality  24860 non-null  object
#  27  url                      24860 non-null  object
# dtypes: float64(1), int64(8), object(19)
# memory usage: 5.5+ MB

# %% [markdown]
# ## Races and circuits

# %%
races_df=pd.read_csv("../data/raw/races.csv")
circuits_df=pd.read_csv("../data/raw/circuits.csv")

# %%
races_df.rename(columns={'name':'race_name','url':'races_url'},inplace=True)
circuits_df.rename(columns={'name':'circuit_name','url':'circuits_url'},inplace=True)

# %%
races_circuits_df=races_df.merge(circuits_df,on='circuitId',how="inner")

# %%
races_circuits_df.drop(columns=['alt'],inplace=True)

# %%
races_circuits_df
# Out:
#       raceId  year  round  circuitId              race_name        date  \
# 0          1  2009      1          1  Australian Grand Prix  2009-03-29
# 1         18  2008      1          1  Australian Grand Prix  2008-03-16
# 2         36  2007      1          1  Australian Grand Prix  2007-03-18
# 3         55  2006      3          1  Australian Grand Prix  2006-04-02
# 4         71  2005      1          1  Australian Grand Prix  2005-03-06
# ...      ...   ...    ...        ...                    ...         ...
# 1030     976  2017      8         73  Azerbaijan Grand Prix  2017-06-25
# 1031     992  2018      4         73  Azerbaijan Grand Prix  2018-04-29
# 1032    1013  2019      4         73  Azerbaijan Grand Prix  2019-04-28
# 1033    1039  2020      9         76      Tuscan Grand Prix  2020-09-13
# 1034    1042  2020     12         75  Portuguese Grand Prix  2020-10-25
#
#           time                                          races_url  \
# 0     06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1     04:30:00  http://en.wikipedia.org/wiki/2008_Australian_G...
# 2     03:00:00  http://en.wikipedia.org/wiki/2007_Australian_G...
# 3     14:00:00  http://en.wikipedia.org/wiki/2006_Australian_G...
# 4     14:00:00  http://en.wikipedia.org/wiki/2005_Australian_G...
# ...        ...                                                ...
# 1030  13:00:00  https://en.wikipedia.org/wiki/2017_Azerbaijan_...
# 1031  12:10:00  https://en.wikipedia.org/wiki/2018_Azerbaijan_...
# 1032  12:10:00  https://en.wikipedia.org/wiki/2019_Azerbaijan_...
# 1033  13:10:00  https://en.wikipedia.org/wiki/2020_Tuscan_Gran...
# 1034  12:10:00  https://en.wikipedia.org/wiki/2020_Portuguese_...
#
#        circuitRef                          circuit_name   location  \
# 0     albert_park        Albert Park Grand Prix Circuit  Melbourne
# 1     albert_park        Albert Park Grand Prix Circuit  Melbourne
# 2     albert_park        Albert Park Grand Prix Circuit  Melbourne
# 3     albert_park        Albert Park Grand Prix Circuit  Melbourne
# 4     albert_park        Albert Park Grand Prix Circuit  Melbourne
# ...           ...                                   ...        ...
# 1030          BAK                     Baku City Circuit       Baku
# 1031          BAK                     Baku City Circuit       Baku
# 1032          BAK                     Baku City Circuit       Baku
# 1033      mugello  Autodromo Internazionale del Mugello    Mugello
# 1034     portimao    Autódromo Internacional do Algarve   Portimão
#
#          country      lat       lng  \
# 0      Australia -37.8497  144.9680
# 1      Australia -37.8497  144.9680
# 2      Australia -37.8497  144.9680
# 3      Australia -37.8497  144.9680
# 4      Australia -37.8497  144.9680
# ...          ...      ...       ...
# 1030  Azerbaijan  40.3725   49.8533
# 1031  Azerbaijan  40.3725   49.8533
# 1032  Azerbaijan  40.3725   49.8533
# 1033       Italy  43.9975   11.3719
# 1034    Portugal  37.2270   -8.6267
#
#                                            circuits_url
# 0     http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1     http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 2     http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 3     http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 4     http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# ...                                                 ...
# 1030     http://en.wikipedia.org/wiki/Baku_City_Circuit
# 1031     http://en.wikipedia.org/wiki/Baku_City_Circuit
# 1032     http://en.wikipedia.org/wiki/Baku_City_Circuit
# 1033       http://en.wikipedia.org/wiki/Mugello_Circuit
# 1034  http://en.wikipedia.org/wiki/Algarve_Internati...
#
# [1035 rows x 15 columns]

# %%
races_circuits_df.to_csv('../data/Modified/races_circuits.csv', index = False,header=True)
