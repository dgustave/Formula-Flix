# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from scipy.stats import norm

# %%
df = pd.read_csv('../data/processed/driver_scores.csv')

# %%
df
# Out:
#        Unnamed: 0  raceId  driverId  Grid Position  Points  laps  \
# 0               0      18         1     1        1    10.0    58
# 1               1      18         2     5        2     8.0    58
# 2               2      18         3     7        3     6.0    58
# 3               3      18         4    11        4     5.0    58
# 4               4      18         5     3        5     4.0    58
# ...           ...     ...       ...   ...      ...     ...   ...
# 24855       24855    1042       825    19       16     0.0    65
# 24856       24856    1042       154    18       17     0.0    65
# 24857       24857    1042       849    20       18     0.0    64
# 24858       24858    1042       826    13       19     0.0    64
# 24859       24859    1042       840    12       \N     0.0    51
#
#        Milliseconds  Fastest Lap Rank  Fastest Lap Time  Fastest Lap Speed  \
# 0          5690.616           39    2            87.452            218.300
# 1          5696.094           41    3            87.739            217.586
# 2          5698.779           41    5            88.090            216.719
# 3          5707.797           58    7            88.603            215.464
# 4          5708.630           43    1            87.418            218.385
# ...             ...          ...  ...               ...                ...
# 24855         0.000           63   16            81.460            205.632
# 24856         0.000           59   17            81.664            205.118
# 24857         0.000           53   19            81.859            204.629
# 24858         0.000           59    8            80.449            208.216
# 24859         0.000           45   18            81.694            205.043
#
#        statusId Win or Loss code       D.O.B Nationality          Full Name
# 0             1         win  HAM  1985-01-07     British     Lewis Hamilton
# 1             1        lost  HEI  1977-05-10      German      Nick Heidfeld
# 2             1        lost  ROS  1985-06-27      German       Nico Rosberg
# 3             1        lost  ALO  1981-07-29     Spanish    Fernando Alonso
# 4             1        lost  KOV  1981-10-19     Finnish  Heikki Kovalainen
# ...         ...         ...  ...         ...         ...                ...
# 24855        11        lost  MAG  1992-10-05      Danish    Kevin Magnussen
# 24856        11        lost  GRO  1986-04-17      French    Romain Grosjean
# 24857        12        lost  LAT  1995-06-29    Canadian    Nicholas Latifi
# 24858        12        lost  KVY  1994-04-26     Russian       Daniil Kvyat
# 24859       130        lost  STR  1998-10-29    Canadian       Lance Stroll
#
# [24860 rows x 18 columns]

# %%
df.drop(columns=['Grid', 'laps', 'Position', 'Points', 'Fastest Lap', 'D.O.B', 'Nationality', 'Unnamed: 0', 'Win or Loss', 'Milliseconds', 'code', 'Fastest Lap Speed', 'statusId'], inplace = True)

# %%
race_df = pd.read_csv('../data/raw/races.csv')
race_df
# Out:
#       raceId  year  round  circuitId                       name        date  \
# 0          1  2009      1          1      Australian Grand Prix  2009-03-29
# 1          2  2009      2          2       Malaysian Grand Prix  2009-04-05
# 2          3  2009      3         17         Chinese Grand Prix  2009-04-19
# 3          4  2009      4          3         Bahrain Grand Prix  2009-04-26
# 4          5  2009      5          4         Spanish Grand Prix  2009-05-10
# ...      ...   ...    ...        ...                        ...         ...
# 1030    1043  2020     13         21  Emilia Romagna Grand Prix  2020-11-01
# 1031    1044  2020     14          5         Turkish Grand Prix  2020-11-15
# 1032    1045  2020     15          3         Bahrain Grand Prix  2020-11-29
# 1033    1046  2020     16          3          Sakhir Grand Prix  2020-12-06
# 1034    1047  2020     17         24       Abu Dhabi Grand Prix  2020-12-13
#
#           time                                                url
# 0     06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1     09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2     07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3     12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4     12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...
# ...        ...                                                ...
# 1030  12:10:00  https://en.wikipedia.org/wiki/2020_Emilia_Roma...
# 1031  10:10:00  https://en.wikipedia.org/wiki/2020_Turkish_Gra...
# 1032  15:10:00  https://en.wikipedia.org/wiki/2020_Bahrain_Gra...
# 1033  17:10:00  https://en.wikipedia.org/wiki/2020_Sakhir_Gran...
# 1034  13:10:00  https://en.wikipedia.org/wiki/2020_Abu_Dhabi_G...
#
# [1035 rows x 8 columns]

# %%
race_df.drop(columns=['round', 'circuitId', 'date', 'time', 'url'], inplace = True) 
race_df
# Out:
#       raceId  year                       name
# 0          1  2009      Australian Grand Prix
# 1          2  2009       Malaysian Grand Prix
# 2          3  2009         Chinese Grand Prix
# 3          4  2009         Bahrain Grand Prix
# 4          5  2009         Spanish Grand Prix
# ...      ...   ...                        ...
# 1030    1043  2020  Emilia Romagna Grand Prix
# 1031    1044  2020         Turkish Grand Prix
# 1032    1045  2020         Bahrain Grand Prix
# 1033    1046  2020          Sakhir Grand Prix
# 1034    1047  2020       Abu Dhabi Grand Prix
#
# [1035 rows x 3 columns]

# %%
df = df.merge(race_df, on = 'raceId', how = 'left')

# %%
df['Driver 1'] = df['driverId']

# %%
df['Driver1_laptime'] = df['Fastest Lap Time']

# %%
df.rename(columns = {'Fastest Lap Time': 'Driver2_laptime'}, inplace= True)

# %%
df
# Out:
#        raceId  driverId Rank  Driver2_laptime          Full Name  year  \
# 0          18         1    2           87.452     Lewis Hamilton  2008
# 1          18         2    3           87.739      Nick Heidfeld  2008
# 2          18         3    5           88.090       Nico Rosberg  2008
# 3          18         4    7           88.603    Fernando Alonso  2008
# 4          18         5    1           87.418  Heikki Kovalainen  2008
# ...       ...       ...  ...              ...                ...   ...
# 24855    1042       825   16           81.460    Kevin Magnussen  2020
# 24856    1042       154   17           81.664    Romain Grosjean  2020
# 24857    1042       849   19           81.859    Nicholas Latifi  2020
# 24858    1042       826    8           80.449       Daniil Kvyat  2020
# 24859    1042       840   18           81.694       Lance Stroll  2020
#
#                         name  Driver 1  Driver1_laptime
# 0      Australian Grand Prix         1           87.452
# 1      Australian Grand Prix         2           87.739
# 2      Australian Grand Prix         3           88.090
# 3      Australian Grand Prix         4           88.603
# 4      Australian Grand Prix         5           87.418
# ...                      ...       ...              ...
# 24855  Portuguese Grand Prix       825           81.460
# 24856  Portuguese Grand Prix       154           81.664
# 24857  Portuguese Grand Prix       849           81.859
# 24858  Portuguese Grand Prix       826           80.449
# 24859  Portuguese Grand Prix       840           81.694
#
# [24860 rows x 9 columns]

# %%
rank_winners_2020 = ['Lewis Hamilton', 'Valtteri Bottas', 'Max Verstappen', 'Sergio Pérez', 'Charles Leclerc', 'Daniel Ricciardo', 'Carlos Sainz', 'Alexander Albon', 'Lando Norris', 'Pierre Gasly']
def name_check(stringy):
    return stringy in rank_winners_2020

# %%
new_df = df[df['Full Name'].map(name_check)]
new_df['Full Name']
# Out:
# 0          Lewis Hamilton
# 26         Lewis Hamilton
# 56         Lewis Hamilton
# 68         Lewis Hamilton
# 89         Lewis Hamilton
#                ...
# 24845        Carlos Sainz
# 24846        Sergio Pérez
# 24848    Daniel Ricciardo
# 24851     Alexander Albon
# 24852        Lando Norris
# Name: Full Name, Length: 1192, dtype: object

# %%
new_df
# Out:
#        raceId  driverId Rank  Driver2_laptime         Full Name  year  \
# 0          18         1    2           87.452    Lewis Hamilton  2008
# 26         19         1    3           95.462    Lewis Hamilton  2008
# 56         20         1   19           95.520    Lewis Hamilton  2008
# 68         21         1    3           82.017    Lewis Hamilton  2008
# 89         22         1    2           86.529    Lewis Hamilton  2008
# ...       ...       ...  ...              ...               ...   ...
# 24845    1042       832    6           80.268      Carlos Sainz  2020
# 24846    1042       815   11           80.802      Sergio Pérez  2020
# 24848    1042       817   14           80.906  Daniel Ricciardo  2020
# 24851    1042       848    5           79.890   Alexander Albon  2020
# 24852    1042       846    3           79.360      Lando Norris  2020
#
#                         name  Driver 1  Driver1_laptime
# 0      Australian Grand Prix         1           87.452
# 26      Malaysian Grand Prix         1           95.462
# 56        Bahrain Grand Prix         1           95.520
# 68        Spanish Grand Prix         1           82.017
# 89        Turkish Grand Prix         1           86.529
# ...                      ...       ...              ...
# 24845  Portuguese Grand Prix       832           80.268
# 24846  Portuguese Grand Prix       815           80.802
# 24848  Portuguese Grand Prix       817           80.906
# 24851  Portuguese Grand Prix       848           79.890
# 24852  Portuguese Grand Prix       846           79.360
#
# [1192 rows x 9 columns]

# %%
new_df_gb = new_df.groupby(['Full Name', 'Driver 1'])['Driver1_laptime', 'Driver2_laptime'].mean()
new_df_gb
# Out:
# <ipython-input-60-1d7448d142e4>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   new_df_gb = new_df.groupby(['Full Name', 'Driver 1'])['Driver1_laptime', 'Driver2_laptime'].mean()
#                            Driver1_laptime  Driver2_laptime
# Full Name        Driver 1
# Alexander Albon  848             87.662303        87.662303
# Carlos Sainz     832             84.740167        84.740167
# Charles Leclerc  844             85.467019        85.467019
# Daniel Ricciardo 817             90.965011        90.965011
# Lando Norris     846             88.388000        88.388000
# Lewis Hamilton   1               89.571771        89.571771
# Max Verstappen   830             85.783746        85.783746
# Pierre Gasly     842             84.602356        84.602356
# Sergio Pérez     815             89.168782        89.168782
# Valtteri Bottas  822             90.828822        90.828822

# %%
new_df_gb = new_df_gb.sort_values(by= ['Driver1_laptime'], ascending= True)

# %%
new_df_gb = new_df_gb.round().astype(int)

# %%
new_df_gb.reset_index(inplace = True)
new_df_gb
# Out:
#           Full Name  Driver 1  Driver1_laptime  Driver2_laptime
# 0      Pierre Gasly       842               85               85
# 1      Carlos Sainz       832               85               85
# 2   Charles Leclerc       844               85               85
# 3    Max Verstappen       830               86               86
# 4   Alexander Albon       848               88               88
# 5      Lando Norris       846               88               88
# 6      Sergio Pérez       815               89               89
# 7    Lewis Hamilton         1               90               90
# 8   Valtteri Bottas       822               91               91
# 9  Daniel Ricciardo       817               91               91

# %%
new_df_gb.drop(columns= 'Full Name', inplace = True)

# %%
# driver_l = new_df_gb['Driver 1'].unique()
# driver_d = {'d1':0, 'd2':0}
# for d1 in driver_l:
#     result = 0
#     for d2 in driver_l:
#         temp = new_df_gb.loc[new_df_gb['Driver 1']== d1] & (new_df_gb.loc[new_df_gb['Driver1_laptime']== d1]) - new_df_gb.loc[new_df_gb['Driver 1']==d1] & (new_df_gb.loc[new_df_gbnew_df_gb['Driver2_laptim']== d2])
#         result = result + temp
#     driver_d[d1] = driver_d[d1] + result

# %%
# race_l = new_df_gb['raceId'].unique()
# driver_l = new_df_gb['Driver 1'].unique()
# driver_d = {'d1':0, 'd2':0}

# for r in race_l:
#     for d1 in driver_l:
#         result = 0
#         for d2 in driver_l:
#             temp = df.loc[df['raceId']== r && df['Driver1_laptime']= d1] - df.loc[df['raceId']==r && df['Driver2_laptim']= d2]
#             result = result + temp
#         driver_d[d1] = driver_d[d1] + result
# data = pd.DataFrame(new_df_gb.to_numpy())
# data.astype(int)
data = pd.DataFrame(new_df_gb.to_numpy(), columns=['Driver 1', 'Driver1_laptime', 'Driver2_laptime'])
data.insert(0, 'Driver 2', range(0, 0 + len(data)), allow_duplicates=True)
data['Driver 1'] = data['Driver 2']
data
# Out:
#    Driver 2  Driver 1  Driver1_laptime  Driver2_laptime
# 0         0         0               85               85
# 1         1         1               85               85
# 2         2         2               85               85
# 3         3         3               86               86
# 4         4         4               88               88
# 5         5         5               88               88
# 6         6         6               89               89
# 7         7         7               90               90
# 8         8         8               91               91
# 9         9         9               91               91

# %%
d = [] 
d.append(data['Driver 2'].pop(data['Driver 2'].iloc[-1]))
for x in data['Driver 2']:
    d.append(x)

# %%
dl = [] 
dl.append(data['Driver2_laptime'].iloc[-1])
for dx in data['Driver2_laptime']:
    dl.append(dx)
# .append(data['Driver2_laptime'])
dl.pop(-1)
# Out:
# 91

# %%
mdata = {'Driver 1': list(data['Driver 1']), 'Driver 2': d, 'Driver1_laptime': list(data['Driver1_laptime']), 'Driver2_laptime': dl}
gd = pd.DataFrame(mdata)
gd
# Out:
#    Driver 1  Driver 2  Driver1_laptime  Driver2_laptime
# 0         0         9               85               91
# 1         1         0               85               85
# 2         2         1               85               85
# 3         3         2               86               85
# 4         4         3               88               86
# 5         5         4               88               88
# 6         6         5               89               88
# 7         7         6               90               89
# 8         8         7               91               90
# 9         9         8               91               91

# %%
def init_linear_regressor_matrix(data, num_of_drivers, col_to_rank):
    
    """initialize linear system matrix for regression"""
    wins = np.zeros((data.shape[0], num_of_drivers))
    score_diff = np.zeros(data.shape[0])

    for index, row in data.iterrows():
        idx1 = row["Driver 1"]
        idx2 = row["Driver 2"]
        if row['Driver1_laptime'] - row['Driver2_laptime'] > 0:
            wins[(index)][(idx1)] = -1
            wins[(index)][(idx2)] = 1
            score_diff[(index)] = row['Driver1_laptime'] - row['Driver2_laptime']
        else:
            wins[(index)][(idx1)] = 1
        wins[(index)][(idx2)] = -1
        score_diff[(index)] = row['Driver2_laptime'] - row['Driver1_laptime']
    wins_df = pd.DataFrame(wins)
    wins_df[col_to_rank] = score_diff
    return wins_df 

def massey(data, num_of_drivers, col_to_rank='delta'):
    """Compute for each driver, adjacency matrix and aggregated scores, as input to the Massey Model"""

    wins_df = init_linear_regressor_matrix(data, num_of_drivers, col_to_rank)
    model = sm.OLS(
           wins_df[col_to_rank], wins_df.drop(columns=[col_to_rank])
       )
    results = model.fit(cov_type='HC1')
    rankings = pd.DataFrame(results.params)
    rankings['std'] = np.sqrt(np.diag(results.cov_params()))
    rankings['consistency'] = (norm.ppf(0.9)-norm.ppf(0.1))*rankings['std']
    rankings = (
         rankings
         .sort_values(by=0, ascending=False)
         .reset_index()
         .rename(columns={"index": "Driver", 0: "massey"})
     )
    rankings = rankings.sort_values(by=["massey"], ascending=False)
    rankings["massey_new"] = rankings["massey"].max() - rankings["massey"]
    return rankings[['Driver', 'massey_new']]

rankings = massey(gd, 10)
rankings
# print(rankings)
# Out:
# C:\Users\Donley\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1886: RuntimeWarning: divide by zero encountered in double_scalars
#   self.het_scale = self.nobs/(self.df_resid)*(self.wresid**2)
# C:\Users\Donley\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1886: RuntimeWarning: invalid value encountered in multiply
#   self.het_scale = self.nobs/(self.df_resid)*(self.wresid**2)
#    Driver    massey_new
# 0       7  0.000000e+00
# 1       4  5.329071e-15
# 2       5  5.329071e-15
# 3       2  1.000000e+00
# 4       0  1.000000e+00
# 5       1  1.000000e+00
# 6       3  6.000000e+00
# 7       9  7.000000e+00
# 8       8  7.000000e+00
# 9       6  7.000000e+00

# %%
# race_l = df['raceId'].unique()
# driver_l = df['Driver 1'].unique()
# driver_d = {'d1':0, 'd2':0}

# for r in race_l:
#     for d1 in driver_l:
#         result = 0
#         for d2 in driver_l:
#             temp = df.loc[df['raceId']== r && df['Driver 1']== d1] - df.loc[df['raceId']==r && df['Driver 2']== d2]
#             result = result + temp
#         driver_d[d1] = driver_d[d1] + result

# %%
# df['Driver 2'] = df['Driver 2'].shift(-1)
